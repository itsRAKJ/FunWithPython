# %%
# !pip install cowsay

# %%
import cowsay

# %%
cowsay.cow("Hello World")
# Out:
#   ___________
# | Hello World |
# ...
#            \
#             \
#               ^__^
#               (oo)\_______
#               (__)\       )\/\
#                   ||----w |
#                   ||     ||

# %%
cowsay.char_names
# Out:
# ['beavis',
#  'cheese',
#  'cow',
#  'daemon',
#  'dragon',
#  'fox',
#  'ghostbusters',
#  'kitty',
#  'meow',
#  'miki',
#  'milk',
#  'octopus',
#  'pig',
#  'stegosaurus',
#  'stimpy',
#  'trex',
#  'turkey',
#  'turtle',
#  'tux']

# %%
cowsay.beavis("Hello World")
# Out:
#   ___________
# | Hello World |
# ...
#                 \
#                  \
#                   \
#                         _------~~-,
#                      ,'            ,
#                      /               \\
#                     /                :
#                    |                  '
#                    |                  |
#                    |                  |
#                     |   _--           |
#                     _| =-.     .-.   ||
#                     o|/o/       _.   |
#                     /  ~          \\ |
#                   (____\@)  ___~    |
#                      |_===~~~.`    |
#                   _______.--~     |
#                   \\________       |
#                            \\      |
#                          __/-___-- -__
#                         /            _ \\

# %%
cowsay.cheese("Hello World")
# Out:
#   ___________
# | Hello World |
# ...
#            \
#             \
#              \
#               \
#                 /     \_/         |
#                |                 ||
#                |                 ||
#               |    ###\  /###   | |
#               |     0  \/  0    | |
#              /|                 | |
#             / |        <        |\ \
#            | /|                 | | |
#            | |     \_______/   |  | |
#            | |                 | / /
#            /||                 /|||
#               ----------------|
#                    | |    | |
#                    ***    ***
#                   /___\  /___\

# %%
cowsay.daemon("Hello World")
# Out:
#   ___________
# | Hello World |
# ...
#                    \
#                     \
#                      \
#                       \
#                        /- _  `-/  '
#                       (/\/ \ \   /\
#                       / /   | `    \
#                       O O   ) /    |
#                       `-^--'`<     '
#                      (_.)  _  )   /
#                       `.___/`    /
#                         `-----' /
#            <----.     __ / __   \
#            <----|====O)))==) \) /====
#            <----'    `--' `.__,' \
#                         |        |
#                          \       /
#                    ______( (_  / \______
#                  ,'  ,-----'   |        \
#                  `--{__________)        \/

# %%
cowsay.dragon("Hello World")
# Out:
#   ___________
# | Hello World |
# ...
#              \
#               \
#                \
#                 \
#                                       / \\  //\\
#                        |\\___/|      /   \\//  \\\\
#                        /0  0  \\__  /    //  | \\ \\
#                       /     /  \\/_/    //   |  \\  \\
#                       \@_^_\@'/   \\/_   //    |   \\   \\
#                       //_^_/     \\/_ //     |    \\    \\
#                    ( //) |        \\///      |     \\     \\
#                  ( / /) _|_ /   )  //       |      \\     _\\
#                ( // /) '/,_ _ _/  ( ; -.    |    _ _\\.-~        .-~~~^-.
#              (( / / )) ,-{        _      `-.|.-~-.           .~         `.
#             (( // / ))  '/\\      /                 ~-. _ .-~      .-~^-.  \\
#             (( /// ))      `.   {            }                   /      \\  \\
#              (( / ))     .----~-.\\        \\-'                 .~         \\  `. \\^-.
# ...

# %%
cowsay.fox("Hello World")
# Out:
#   ___________
# | Hello World |
# ...
#             \
#              \
#               \
#                |\_/|,,_____,~~`
#                (.".)~~     )`~}}
#                 \o/\ /---~\\ ~}}
#                   _//    _// ~}

# %%
cowsay.ghostbusters("Hello World")
# Out:
#   ___________
# | Hello World |
# ...
#                    \
#                     \
#                      \
#                       \
#                                   __---__
#                                _-       /--______
#                           __--( /     \ )XXXXXXXXXXX\v.
#                         .-XXX(   O   O  )XXXXXXXXXXXXXXX-
#                        /XXX(       U     )        XXXXXXX\
#                      /XXXXX(              )--_  XXXXXXXXXXX\
#                     /XXXXX/ (      O     )   XXXXXX   \XXXXX\
#                     XXXXX/   /            XXXXXX   \__ \XXXXX
#                     XXXXXX__/          XXXXXX         \__---->
#             ---___  XXX__/          XXXXXX      \__         /
#               \-  --__/   ___/\  XXXXXX            /  ___--/=
#                \-\    ___/    XXXXXX              '--- XXXXXX
#                   \-\/XXX\ XXXXXX                      /XXXXX
#                     \XXXXXXXXX   \                    /XXXXX/
# ...

# %%
cowsay.kitty("Hello World")
# Out:
#   ___________
# | Hello World |
# ...
#               \
#                \
#                 \
#                  \
#                   ("`-'  '-/") .___..--' ' "`-._
#                    ` *_ *  )    `-.   (      ) .`-.__. `)
#                     (_Y_.) ' ._   )   `._` ;  `` -. .-'
#                  _.. `--'_..-_/   /--' _ .' ,4
#                 ( i l ),-''  ( l i),'  ( ( ! .-'

# %%
cowsay.meow("Hello World")
# Out:
#   ___________
# | Hello World |
# ...
#            \
#             \
#              \
#               \
#                              _ ___.--'''`--''//-,-_--_.
#                  \\`"' ` || \\\\ \\ \\\\/ / // / ,-\\\\`,_
#                 /'`  \\ \\ || Y  | \\|/ / // / - |__ `-,
#                /\@"\\  ` \\ `\\ |  | ||/ // | \\/  \\  `-._`-,_.,
#               /  _.-. `.-\\,___/\\ _/|_/_\\_\\/|_/ |     `-._._)
#               `-'``/  /  |  // \\__/\\__  /  \\__/ \\
#                    `-'  /-\\/  | -|   \\__ \\   |-' |
#                      __/\\ / _/ \\/ __,-'   ) ,' _|'
#                     (((__/(((_.' ((___..-'((__,'

# %%
cowsay.miki("Hello World")
# Out:
#   ___________
# | Hello World |
# ...
#            \
#             \                  &************************&
#              \             &******************************&
#               \          &**********************************&
#                        &**************************************&
#                      &*****************************************&
#                     &*******************************************&
#                    &*********************************************&
#                   &***********************************************&
#                  &************************************************&
#                  &***#########********#########*******************&
#                  &*##       ##########          ##################&
#                  &*##   O   ##@**####   O       ##***************&
#                  &***#########@*******#########*****************&
#                  &***********@*********************************&
# ...

# %%
cowsay.milk("Hello World")
# Out:
#   ___________
# | Hello World |
# ...
#            \
#             \
#              \
#               \
#                   ____________
#                   |__________|
#                  /           /\
#                 /           /  \
#                /___________/___/|
#                |          |     |
#                |  ==\ /== |     |
#                |   O   O  | \ \ |
#                |     <    |  \ \|
#               /|          |   \ \
#              / |  \_____/ |   / /
#             / /|          |  / /|
#            /||\|          | /||\/
#                -------------|
#                    | |    | |
#                   <__/    \__>

# %%
cowsay.octopus("Hello World")
# Out:
#   ___________
# | Hello World |
# ...
#                 \
#                  \
#                   \
#                                    . . .
#                                  .   ^   .
#                                 .  ^ ^ ^  .
#                                 .  ^ ^ ^  .
#                                  .   ^    .
#                                    . . .
#                      _ _ _ _ _ _ _|     |_ _ _ _ _ _
#                     /  _ _ _ _ _ _| o|o |_ _ _ _ _ _ \
#                    / /  _ _ _  _ _|  |  |_ _ _ _    \ \
#                   / /  /  _ _ _ / /| |\ \ _ _ _  \   \ \
#                  / /  /  /     / / | | \ \     \  \   \ \
#                 / /  /  /     / /  | |  \ \     \  \   \ \
#                /_/  /  /     / /   | |   \ \     \  \   \_\
#                 |  /__/     /_/    |_|    \_\     \__\   |
#                      |      /       |       \       |

# %%
cowsay.pig("Hello World")
# Out:
#   ___________
# | Hello World |
# ...
#            \
#             \
#              \
#               \
#                         ,.
#                        (_|,.
#                        ,' /, )_______   _
#                    __j o``-'        `.'-)'
#                    (")                 \'
#                    `-j                |
#                      `-._(           /
#                         |_\  |--^.  /
#                        /_]'|_| /_)_/
#                            /_]'  /_]'

# %%
cowsay.stegosaurus("Hello World")
# Out:
#   ___________
# | Hello World |
# ...
#                  \
#                   \
#                    \
#                     \
#                                        .       .
#                                       / `.   .' \
#                               .---.  <    > <    >  .---.
#                               |    \  \ - ~ ~ - /  /    |
#                   _____        ~-..-~             ~-..-~
#                  |     |   \~~~\.'                    `./~~~/
#                 ---------   \__/                        \__/
#                .'  O    \     /               /       \  "
#               (_____,    `._.'               |         }  \/~~~/
#                `----.          /       }     |        /    \__/
#                      `-.      |       /      |       /      `. ,~~|
#                          ~-.__|      /_ - ~ ^|      /- _      `..-'   f:  f:
#                               |     /        |     /     ~-.     `-. _|| _||_
# ...

# %%
cowsay.stimpy("Hello World")
# Out:
#   ___________
# | Hello World |
# ...
#             \
#              \
#               \
#                \
#                    .    _  .
#                   |\_|/__/|
#                   / / \/ \  \
#                  /__|O||O|__ \
#                 |/_ \_/\_/ _\ |
#                 | | (____) | ||
#                 \/\___/\__/  //
#                 (_/         ||
#                  |          ||
#                  |          ||\
#                   \        //_/
#                    \______//
#                   __ || __||
#                  (____(____)

# %%
cowsay.trex("Hello World")
# Out:
#   ___________
# | Hello World |
# ...
#                   \
#                    \
#                     \
#                      \
#                         .-=-==--==--.
#                   ..-=="  ,'o`)      `.
#                 ,'         `"'         \
#                :  (                     `.__...._
#                |                  )    /         `-=-.
#                :       ,vv.-._   /    /               `---==-._
#                 \/\/\/VV ^ d88`;'    /                         `.
#                     ``  ^/d88P!'    /             ,              `._
#                        ^/    !'   ,.      ,      /                  "-,,__,,--'""""-.
#                       ^/    !'  ,'  \ . .(      (         _           )  ) ) ) ))_,-.\
#                      ^(__ ,!',"'   ;:+.:%:a.     \:.. . ,'          )  )  ) ) ,"'    '
#                      ',,,'','     /o:::":%:%a.    \:.:.:         .    )  ) _,'
#                       """'       ;':::'' `+%%%a._  \%:%|         ;.). _,-""
# ...

# %%
cowsay.turkey("Hello World")
# Out:
#   ___________
# | Hello World |
# ...
#                    \
#                     \
#                      \
#                       \
#                                                         ,+*^^*+___+++_
#                                                   ,*^^^^              )
#                                                _+*                     ^**+_
#                                              +^       _ _++*+_+++_,         )
#                          _+^^*+_    (     ,+*^ ^          \\+_        )
#                         {       )  (    ,(    ,_+--+--,      ^)      ^\\
#                        { (\@)    } f   ,(  ,+-^ __*_*_  ^^\\_   ^\\       )
#                       {:;-/    (_+*-+^^^^^+*+*<_ _++_)_    )    )      /
#                      ( /  (    (        ,___    ^*+_+* )   <    <      \\
#                       U _/     )    *--<  ) ^\\-----++__)   )    )       )
#                        (      )  _(^)^^))  )  )\\^^^^^))^*+/    /       /
# ...

# %%
cowsay.turtle("Hello World")
# Out:
#   ___________
# | Hello World |
# ...
#              \
#               \
#                \
#                 \
#                                            ___-------___
#                                        _-~~             ~~-_
#                                     _-~                    /~-_
#                   /^\__/^\         /~  \                   /    \
#                 /|  O|| O|        /      \_______________/        \
#                | |___||__|      /       /                \          \
#                |          \    /      /                    \          \
#                |   (_______) /______/                        \_________ \
#                |         / /         \                      /            \
#                 \         \^\\         \                  /               \     /
#                   \         ||           \______________/      _-_       //\__//
#                     \       ||------_-~~-_ ------------- \ --/~   ~\    || __/
# ...

# %%
cowsay.tux("Hello World")
# Out:
#   ___________
# | Hello World |
# ...
#                 \
#                  \
#                   \
#                    .--.
#                   |o_o |
#                   |:_/ |
#                  //   \ \
#                 (|     | )
#                /'\_   _/`\
#                \___)=(___/
